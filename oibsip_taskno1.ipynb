# %% [markdown]
# # Created By ~
# ## Sambhav Srivastava

# %% [markdown]
# # Task 2
# ## Unemployment Analysis with Python

# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
df=exel=pd.read_csv("C:\\Users\\Sambh\\Downloads\\archive (1)\\Unemployment_Rate_upto_11_2020.csv")
df
# Out:
#              Region         Date Frequency  UnempRate  EstimatedEmployed  \
# 0    Andhra Pradesh   31-01-2020         M       5.48           16635535
# 1    Andhra Pradesh   29-02-2020         M       5.83           16545652
# 2    Andhra Pradesh   31-03-2020         M       5.79           15881197
# 3    Andhra Pradesh   30-04-2020         M      20.51           11336911
# 4    Andhra Pradesh   31-05-2020         M      17.43           12988845
# ..              ...          ...       ...        ...                ...
# 262     West Bengal   30-06-2020         M       7.29           30726310
# 263     West Bengal   31-07-2020         M       6.83           35372506
# 264     West Bengal   31-08-2020         M      14.87           33298644
# 265     West Bengal   30-09-2020         M       9.35           35707239
# 266     West Bengal   31-10-2020         M       9.98           33962549
#
#      EstimatedLabourParticipationRate Region.1      lon     lat
# ...

# %%
df.Region.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Region                              0
# Date                                0
# Frequency                           0
# UnempRate                           0
# EstimatedEmployed                   0
# EstimatedLabourParticipationRate    0
# Region.1                            0
# lon                                 0
# lat                                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Region                               object
# Date                                 object
# Frequency                            object
# UnempRate                           float64
# EstimatedEmployed                     int64
# EstimatedLabourParticipationRate    float64
# Region.1                             object
# lon                                 float64
# lat                                 float64
# dtype: object

# %%
df.describe()
# Out:
#         UnempRate  EstimatedEmployed  EstimatedLabourParticipationRate  \
# count  267.000000       2.670000e+02                        267.000000
# mean    12.236929       1.396211e+07                         41.681573
# std     10.803283       1.336632e+07                          7.845419
# min      0.500000       1.175420e+05                         16.770000
# 25%      4.845000       2.838930e+06                         37.265000
# 50%      9.650000       9.732417e+06                         40.390000
# 75%     16.755000       2.187869e+07                         44.055000
# max     75.850000       5.943376e+07                         69.690000
#
#               lon         lat
# count  267.000000  267.000000
# mean    22.826048   80.532425
# std      6.270731    5.831738
# min     10.850500   71.192400
# 25%     18.112400   76.085600
# 50%     23.610200   79.019300
# 75%     27.278400   85.279900
# max     33.778200   92.937600

# %%
lats_longs_weight1= list(map(list, zip(df["lon"], df["lat"], df["UnempRate"])))

# %%
map_obj1 = folium.Map(location =[20.5937,78.9629], zoom_start=5)
HeatMap(lats_longs_weight1).add_to(map_obj1)
print("Unemployment Rate:")
map_obj1
# Out:
# Unemployment Rate:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
lats_longs_weight2= list(map(list, zip(df["lon"], df["lat"], df["EstimatedEmployed"])))

# %%
map_obj2 = folium.Map(location =[20.5937,78.9629], zoom_start=5)
HeatMap(lats_longs_weight2).add_to(map_obj2)
print("People Empolyed")
map_obj2
# Out:
# People Empolyed
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
lats_longs_weight3= list(map(list, zip(df["lon"], df["lat"], df["EstimatedLabourParticipationRate"])))

# %%
map_obj3 = folium.Map(location =[20.5937,78.9629], zoom_start=5)
HeatMap(lats_longs_weight3).add_to(map_obj3)
print("Estimated labour Particiption rate")
map_obj3
# Out:
# Estimated labour Particiption rate
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Contact me at-
# ### Sambhavsrivastava2401@gmail.com
